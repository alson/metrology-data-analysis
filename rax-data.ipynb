# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
values = [
9.9999999, 10.0000002, 10.0000006, 10.0000002, 10.0000003, 10.0000001, 10.0000002, 10.0000005, 10.0000008, 10.0000007, 10.0000005, 10.0000005, 10.0000004, 10.0000004, 10.0000003, 10.0000004, 10.0000004, 10.0000004, 10.0000004, 10.0000008, 10.0000012, 10.0000012, 10.0000016, 10.0000018, 10.0000018, 10.0000015, 10.0000016, 10.0000017, 10.0000016, 10.0000015, 10.0000011, 10.0000012, 10.0000002, 10.0000005, 10.0000003, 10.0000000, 10.0000001, 10.0000001, 10.0000003,
]

# %%
np.mean(values)
# Out:
# 10.000000700000001

# %%
np.std(values, ddof=1)
# Out:
# 5.762857477153242e-07

# %%
plt.plot(values)

# %%
10/365
# Out:
# 0.0273972602739726
